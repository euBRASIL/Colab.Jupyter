# %% [markdown]
# <a href="https://colab.research.google.com/github/euBRASIL/Colab.Jupyter/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
bankdados = pd.DataFrame()

# %%
chave = {'hexadecimal':'00000000000000000000000000000000000000000000000300000000863e02bc', 'wif':'5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg7QufWQVAAE', 'bitcoin':'13RgQhQfWkNp2h2JTHpP9GVc6iPJTMhTeR','%':'29.41'}


chave_privada = {
'hexadecimal':'00000000000000000000000000000000000000000000000300000000863e02bc', 'wif':'5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg7QufWQVAAE', 'bitcoin':'13RgQhQfWkNp2h2JTHpP9GVc6iPJTMhTeR','%':'29.41',
'hexadecimal':'00000000000000000000000000000000000000000000000300000000866327aa', 'wif':'5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg8pYqLiwYmT', 'bitcoin':'131KzB2fWVDUES7ZC8iMfA4JnPxeHH48qo','%':'29.41'
}

print(chave_privada['hexadecimal'])
# Out:
# 00000000000000000000000000000000000000000000000300000000866327aa

# %%
lista = [['hexadecimal':'00000000000000000000000000000000000000000000000300000000863e02bc', 'wif':'5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg7QufWQVAAE', 'bitcoin':'13RgQhQfWkNp2h2JTHpP9GVc6iPJTMhTeR','%':'29.41'],
['hexadecimal':'00000000000000000000000000000000000000000000000300000000866327aa', 'wif':'5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg8pYqLiwYmT', 'bitcoin':'131KzB2fWVDUES7ZC8iMfA4JnPxeHH48qo','%':'29.41']]


capitais = [['Acre', 'AC', '803,5 mil', 'Rio Branco'],
            ['Amapá', 'AP', '776,6 mil', 'Macapá'],
            ['Amazonas', 'AM', '3,9 milhões', 'Manaus'],
            ['Pará', 'PA', '8,1 milhões', 'Belém'],
            ['Rondônia', 'RO', '1,7 milhão', 'Porto Velho'],
            ['Roraima', 'RR', '505,6 mil', 'Boa Vista'],
            ['Tocantins', 'TO', '1,5 milhão', 'Palmas']]

# %%
banco = [['00000000000000000000000000000000000000000000000300000000863e02bc', '5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg7QufWQVAAE', '13RgQhQfWkNp2h2JTHpP9GVc6iPJTMhTeR','29.41'],
['00000000000000000000000000000000000000000000000300000000866327aa', '5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg8pYqLiwYmT', '131KzB2fWVDUES7ZC8iMfA4JnPxeHH48qo','29.41']]

display(banco)

db_chave_privada = pd.DataFrame(banco, columns=['Chave Privada', 'WIF', 'Endereço de Bitcoin', '% Percentual'])

display(db_chave_privada)
# Out:
# [['00000000000000000000000000000000000000000000000300000000863e02bc',
#   '5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg7QufWQVAAE',
#   '13RgQhQfWkNp2h2JTHpP9GVc6iPJTMhTeR',
#   '29.41'],
#  ['00000000000000000000000000000000000000000000000300000000866327aa',
#   '5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg8pYqLiwYmT',
#   '131KzB2fWVDUES7ZC8iMfA4JnPxeHH48qo',
#   '29.41']]
#                                        Chave Privada  \
# 0  0000000000000000000000000000000000000000000000...
# 1  0000000000000000000000000000000000000000000000...
#
#                                                  WIF  \
# 0  5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg7QufW...
# 1  5HpHagT65TZzG1PH3CSu63k8DbpvD8s5ipKGp2Rbg8pYqL...
#
#                   Endereço de Bitcoin % Percentual
# 0  13RgQhQfWkNp2h2JTHpP9GVc6iPJTMhTeR        29.41
# 1  131KzB2fWVDUES7ZC8iMfA4JnPxeHH48qo        29.41

# %%
bloco = {

'Chave': {

0: 'Acre',
1: 'Amapá',
2: 'Amazonas',
3: 'Pará',
4: 'Rondônia',
5: 'Roraima',
6: 'Tocantins'

},'Sigla': {

0: 'AC',
1: 'AP',
2: 'AM',
3: 'PA',
4: 'RO',
5: 'RR',
6: 'TO'

},'População': {

0: '803,5 mil',
1: '776,6 mil',
2: '3,9 milhões',
3: '8,1 milhões',
4: '1,7 milhão',
5: '505,6 mil',
6: '1,5 milhão'

},'Capital': {

0: 'Rio Branco',
1: 'Macapá',
2: 'Manaus',
3: 'Belém',
4: 'Porto Velho',
5: 'Boa Vista',
6: 'Palmas'

}}

df = pd.DataFrame(bloco)

print(df)
display(df)
# Out:
#        Chave Sigla    População      Capital
# 0       Acre    AC    803,5 mil   Rio Branco
# 1      Amapá    AP    776,6 mil       Macapá
# 2   Amazonas    AM  3,9 milhões       Manaus
# 3       Pará    PA  8,1 milhões        Belém
# 4   Rondônia    RO   1,7 milhão  Porto Velho
# 5    Roraima    RR    505,6 mil    Boa Vista
# 6  Tocantins    TO   1,5 milhão       Palmas
#        Chave Sigla    População      Capital
# 0       Acre    AC    803,5 mil   Rio Branco
# 1      Amapá    AP    776,6 mil       Macapá
# 2   Amazonas    AM  3,9 milhões       Manaus
# 3       Pará    PA  8,1 milhões        Belém
# 4   Rondônia    RO   1,7 milhão  Porto Velho
# 5    Roraima    RR    505,6 mil    Boa Vista
# 6  Tocantins    TO   1,5 milhão       Palmas
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# ...
